# %%
import pandas as pd
df=pd.read_csv("Finance_data.csv")
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
print(df)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='str')

# %%
df.shape
# Out:
# (40, 24)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     str
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     str
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     str
#  11  Factor                             40 non-null     str
# ...

# %%
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
df.isnull().sum()
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
result = df[["gender","age","Investment_Avenues","Objective","Duration","Avenue"]]
print(result)
# Out:
#     gender  age Investment_Avenues             Objective           Duration  \
# 0   Female   34                Yes  Capital Appreciation          1-3 years
# 1   Female   23                Yes  Capital Appreciation  More than 5 years
# 2     Male   30                Yes  Capital Appreciation          3-5 years
# 3     Male   22                Yes                Income   Less than 1 year
# 4   Female   24                 No                Income   Less than 1 year
# 5   Female   24                 No  Capital Appreciation          1-3 years
# 6   Female   27                Yes  Capital Appreciation          3-5 years
# 7     Male   21                Yes  Capital Appreciation          3-5 years
# 8     Male   35                Yes                Growth          1-3 years
# 9     Male   31                Yes  Capital Appreciation          3-5 years
# 10  Female   35                Yes                Growth          3-5 years
# ...

# %%
result=df.loc[df["age"]>30,["gender","age","Avenue","Objective"]]
print(result)
# Out:
#     gender  age          Avenue             Objective
# 0   Female   34     Mutual Fund  Capital Appreciation
# 8     Male   35          Equity                Growth
# 9     Male   31  Fixed Deposits  Capital Appreciation
# 10  Female   35     Mutual Fund                Growth
# 25  Female   32     Mutual Fund                Growth
# 27    Male   31  Fixed Deposits                Growth
# 29  Female   34     Mutual Fund                Income
# 31  Female   31  Fixed Deposits  Capital Appreciation
# 38    Male   31          Equity                Growth

# %%
result=df.loc[(df["gender"]=="Female")& (df["age"]>30),["age","Avenue","Duration"]]
print(result)
# Out:
#     age          Avenue   Duration
# 0    34     Mutual Fund  1-3 years
# 10   35     Mutual Fund  3-5 years
# 25   32     Mutual Fund  3-5 years
# 29   34     Mutual Fund  3-5 years
# 31   31  Fixed Deposits  3-5 years

# %%
result=df.loc[df["Avenue"]=="Equity",["gender","age","Objective","Avenue","Duration"]]
print(result)
# Out:
#     gender  age             Objective  Avenue          Duration
# 2     Male   30  Capital Appreciation  Equity         3-5 years
# 3     Male   22                Income  Equity  Less than 1 year
# 4   Female   24                Income  Equity  Less than 1 year
# 6   Female   27  Capital Appreciation  Equity         3-5 years
# 8     Male   35                Growth  Equity         1-3 years
# 21  Female   24  Capital Appreciation  Equity         3-5 years
# 28    Male   29  Capital Appreciation  Equity         1-3 years
# 32    Male   27  Capital Appreciation  Equity         3-5 years
# 36    Male   30  Capital Appreciation  Equity         1-3 years
# 38    Male   31                Growth  Equity         1-3 years

# %%
print("Source"in df.columns)
# Out:
# False

# %%
import pandas as pd
df=pd.read_csv("Finance_data.csv")
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
print(df.shape)
# Out:
# (40, 24)

# %%
print(df.columns.tolist())
# Out:
# ['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market', 'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold', 'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration', 'Invest_Monitor', 'Expect', 'Avenue', 'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual', 'Reason_Bonds', 'Reason_FD', 'Source']

# %%
result=df.loc[df["Avenue"]=="Equity",["gender","age","Objective","Avenue","Duration","Source"]]
print(result)
# Out:
#     gender  age             Objective  Avenue          Duration  \
# 2     Male   30  Capital Appreciation  Equity         3-5 years
# 3     Male   22                Income  Equity  Less than 1 year
# 4   Female   24                Income  Equity  Less than 1 year
# 6   Female   27  Capital Appreciation  Equity         3-5 years
# 8     Male   35                Growth  Equity         1-3 years
# 21  Female   24  Capital Appreciation  Equity         3-5 years
# 28    Male   29  Capital Appreciation  Equity         1-3 years
# 32    Male   27  Capital Appreciation  Equity         3-5 years
# 36    Male   30  Capital Appreciation  Equity         1-3 years
# 38    Male   31                Growth  Equity         1-3 years
#
#                       Source
# 2                 Television
# 3                   Internet
# 4                   Internet
# 6      Financial Consultants
# 8                 Television
# 21  Newspapers and Magazines
# 28                Television
# ...

# %%
result=df.loc[(df["Investment_Avenues"]=="Yes")& (df["Stock_Marktet"]=="Yes"),["gender","age","Avenue","Objective"]]
print(result)
# Out:
#     gender  age                 Avenue             Objective
# 0   Female   34            Mutual Fund  Capital Appreciation
# 2     Male   30                 Equity  Capital Appreciation
# 3     Male   22                 Equity                Income
# 6   Female   27                 Equity  Capital Appreciation
# 7     Male   21            Mutual Fund  Capital Appreciation
# 8     Male   35                 Equity                Growth
# 9     Male   31         Fixed Deposits  Capital Appreciation
# 10  Female   35            Mutual Fund                Growth
# 11    Male   29            Mutual Fund  Capital Appreciation
# 13  Female   28            Mutual Fund  Capital Appreciation
# 14  Female   25         Fixed Deposits  Capital Appreciation
# 15    Male   27            Mutual Fund  Capital Appreciation
# 16  Female   28         Fixed Deposits                Growth
# 17    Male   27            Mutual Fund  Capital Appreciation
# ...

# %%
result=df.loc[df["Expect"]=="20%-30%"]
print(result)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 4   Female   24                 No             2              1           3
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 10  Female   35                Yes             2              4           7
# 11    Male   29                Yes             2              5           7
# 12  Female   21                 No             1              2           3
# 13  Female   28                Yes             2              3           7
# ...
